# %%
import pandas as pd
import numpy as  np

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
df = pd.read_json("/content/DataEngineeringQ2.json")

# %%
df.head()
# Out:
#         _id appointmentId                                     patientDetails  \
# 0  T6hf3rb5     40d2-9c9f  {'_id': 'T6hb630b3', 'firstName': 'Css', 'last...
# 1  T65g3rb5      40dbtc9f  {'_id': 'T6h33b300', 'firstName': 'Lokesh', 'l...
# 2  T7g6Srb5      g3Wt5c9f  {'_id': 'TjhB4373', 'phrId': '63b5hvy614d5', '...
# 3  94bg8W8d      fb6-a535  {'_id': '6df4R5b', 'phrId': '644nig7y', 'first...
# 4  T6h8H56c       67h7KL9  {'_id': 'lK9hy06a', 'firstName': 'Raghu Viju',...
#
#    phoneNumber                                   consultationData
# 0  96686896670  {'adviceTemplates': [], 'advices': [], 'attach...
# 1   9496368916  {'adviceTemplates': [], 'advices': [], 'attach...
# 2   7787204833  {'adviceTemplates': [], 'advices': [], 'attach...
# 3   9376756879  {'adviceTemplates': [], 'advices': [], 'attach...
# 4   5267384241  {'adviceTemplates': [], 'advices': [], 'attach...

# %%
df3 = pd.DataFrame(df["consultationData"])

# %%
df3
# Out:
# 0    {'adviceTemplates': [], 'advices': [], 'attach...
# 1    {'adviceTemplates': [], 'advices': [], 'attach...
# 2    {'adviceTemplates': [], 'advices': [], 'attach...
# 3    {'adviceTemplates': [], 'advices': [], 'attach...
# 4    {'adviceTemplates': [], 'advices': [], 'attach...
# Name: consultationData, dtype: object

# %%
df2 = pd.DataFrame(df["patientDetails"])

# %%
# prompt: convert this into dataframe

import pandas as pd
import numpy as  np
from google.colab import drive
drive.mount('/content/drive')
df = pd.read_json("/content/DataEngineeringQ2.json")
df2 = pd.DataFrame(df["patientDetails"])

# Assuming df2 contains a column named 'patientDetails' with nested data
normalized_df = pd.json_normalize(df2['patientDetails'])

# Display the normalized DataFrame
print(normalized_df)
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
#                        _id                 firstName     lastName emailId  \
# 0                T6hb630b3                       Css
# 1                T6h33b300                    Lokesh
# 2                 TjhB4373                     Shila          Das
# 3                  6df4R5b                   Bhavika  Ben Panchal
# 4                 lK9hy06a                Raghu Viju
# 5                  kI9d5c6              Dinesh Kumar
# 6                 i9R324b7                     Lalit     Sankhwal
# 7   T6h41b5ad3d8002ad9c3c4                      Ravi
# 8                 T9Iy347e                    Dinesh
# 9                  T4Rb1a2                    Sanjay
# 10                Tr4T2173                    Akshay       Akshay
# 11                  T6Wa50                   Nirmala
# 12                 65sRa36                    Satish
# ...

# %%
# Calculate the average number of medicines prescribed in the dataset.

df2.head()
# Out:
#                                       patientDetails
# 0  {'_id': 'T6hb630b3', 'firstName': 'Css', 'last...
# 1  {'_id': 'T6h33b300', 'firstName': 'Lokesh', 'l...
# 2  {'_id': 'TjhB4373', 'phrId': '63b5hvy614d5', '...
# 3  {'_id': '6df4R5b', 'phrId': '644nig7y', 'first...
# 4  {'_id': 'lK9hy06a', 'firstName': 'Raghu Viju',...

# %%
# prompt: Determine the 3rd most frequently prescribed medicineName in DataEngineeringQ2.json

import pandas as pd
import numpy as  np
from google.colab import drive
drive.mount('/content/drive')
df = pd.read_json("/content/DataEngineeringQ2.json")
df2 = pd.DataFrame(df["patientDetails"])

# Assuming df2 contains a column named 'patientDetails' with nested data
normalized_df = pd.json_normalize(df2['patientDetails'])

# Count the occurrences of each medicineName
medicine_counts = normalized_df['medicines.medicineName'].value_counts()

# Get the 3rd most frequent medicine
third_most_frequent = medicine_counts.iloc[2:3]
print(third_most_frequent)
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexes/base.py in get_loc(self, key)
#    3652         try:
# -> 3653             return self._engine.get_loc(casted_key)
#    3654         except KeyError as err:
#
# /usr/local/lib/python3.10/dist-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# /usr/local/lib/python3.10/dist-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'medicines.medicineName'
#
# ...

# %%
normalized_df.isna().sum()
# Out:
# _id                  0
# firstName            0
# lastName             0
# emailId              1
# gender               9
# alternateContact    22
# birthDate           10
# phrId               23
# customId            15
# chat._id            15
# chat.channelId      30
# dtype: int64

# %%
normalized_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 31 entries, 0 to 30
# Data columns (total 11 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   _id               31 non-null     object
#  1   firstName         31 non-null     object
#  2   lastName          31 non-null     object
#  3   emailId           30 non-null     object
#  4   gender            22 non-null     object
#  5   alternateContact  9 non-null      object
#  6   birthDate         21 non-null     object
#  7   phrId             8 non-null      object
#  8   customId          16 non-null     object
#  9   chat._id          16 non-null     object
#  10  chat.channelId    1 non-null      object
# dtypes: object(11)
# memory usage: 2.8+ KB

# %%
# What is the percentage of female gender after imputation of gender column basis mode.
normalized_df["gender"] ==
# Out:
# 0
# 1       M
# 2     NaN
# 3       F
# 4     NaN
# 5       M
# 6       M
# 7     NaN
# 8       M
# 9       M
# 10      M
# 11      F
# 12    NaN
# 13      F
# 14    NaN
# 15      F
# 16      M
# 17      F
# 18      F
# 19    NaN
# 20      F
# 21      M
# 22      F
# 23    NaN
# 24      M
# 25    NaN
# 26    NaN
# 27      F
# 28      F
# 29      M
# 30      M
# Name: gender, dtype: object

# %%
# prompt: Calculate the average number of medicines prescribed in the dataset.

import pandas as pd
import numpy as  np
from google.colab import drive
drive.mount('/content/drive')
df = pd.read_json("/content/DataEngineeringQ2.json")
df2 = pd.DataFrame(df["patientDetails"])

# Assuming df2 contains a column named 'patientDetails' with nested data
normalized_df = pd.json_normalize(df2['patientDetails'])

# Calculate the number of medicines for each patient
num_medicines_per_patient = normalized_df['medicines'].apply(len)

# Calculate the average number of medicines
average_medicines = num_medicines_per_patient.mean()
print(average_medicines)
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexes/base.py in get_loc(self, key)
#    3652         try:
# -> 3653             return self._engine.get_loc(casted_key)
#    3654         except KeyError as err:
#
# /usr/local/lib/python3.10/dist-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# /usr/local/lib/python3.10/dist-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'medicines'
#
# ...

# %%
# Initialize a counter for the total number of medicines and the number of entries
total_medicines_count = 0
total_entries = 0

# Iterate through the data to count the total number of medicines and the number of entries
for entry in data:
    consultation_data = entry.get('consultationData', {})
    medicines = consultation_data.get('medicines', [])
    total_medicines_count += len(medicines)
    total_entries += 1

# Calculate the average number of medicines prescribed per entry
average_medicines_prescribed = total_medicines_count / total_entries

average_medicines_prescribed

# %%
# Initialize counters for active and inactive medicines
active_count = 0
inactive_count = 0

# Iterate through the data to count active and inactive medicines
for entry in data:
    consultation_data = entry.get('consultationData', {})
    medicines = consultation_data.get('medicines', [])
    for medicine in medicines:
        if medicine.get('isActive'):
            active_count += 1
        else:
            inactive_count += 1

# Calculate the total number of medicines
total_medicines = active_count + inactive_count

# Calculate the percentage distribution
active_percentage = (active_count / total_medicines) * 100
inactive_percentage = (inactive_count / total_medicines) * 100

active_percentage, inactive_percentage
